# %% [markdown]
# # Train Models for Different Players
# We will use Logistic Regression to train the shot data of different NBA players, and record the coefficients into a file.

# %% [markdown]
# ### 1. Read the data

# %%
import os
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer, roc_auc_score, f1_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# %% [markdown]
# Specify data path

# %%
data_path = './shot_data'

# %% [markdown]
# Get the file name of all players

# %%
fname_list = os.listdir(data_path)
fpath_list = []
id_list = []

for fname in fname_list:
    fpath = os.path.join(data_path, fname)
    if os.path.isfile(fpath):
        fpath_list.append(fpath)
        player_id = fname.split('_')[-1].split('.')[0]  # Splitting again to remove file extension
        try:
            id_list.append(int(player_id))
        except ValueError:
            print(f"Filename {fname} does not end with a player ID")

# %%
print(id_list)
# Out:
# [101108, 1626145, 1626156, 1626157, 1626162, 1626166, 1626167, 1626168, 1626171, 1626172, 1626179, 1626181, 1626192, 1626196, 1626204, 1626220, 1626224, 1627734, 1627739, 1627741, 1627742, 1627747, 1627749, 1627750, 1627751, 1627752, 1627777, 1627783, 1627826, 1627827, 1627832, 1627884, 1627936, 1628365, 1628368, 1628369, 1628370, 1628372, 1628374, 1628378, 1628379, 1628380, 1628381, 1628392, 1628398, 1628401, 1628404, 1628420, 1628470, 1628975, 1628976, 1628978, 1628983, 1628984, 1628988, 1628989, 1628991, 1628995, 1628997, 1629001, 1629003, 1629006, 1629008, 1629012, 1629013, 1629014, 1629018, 1629020, 1629021, 1629022, 1629023, 1629026, 1629027, 1629029, 1629060, 1629111, 1629130, 1629216, 1629234, 1629312, 1629611, 1629614, 1629622, 1629629, 1629630, 1629631, 1629632, 1629636, 1629639, 1629640, 1629651, 1629652, 1629655, 1629656, 1629659, 1629661, 1629667, 1629670, 1629673, 1629675, 1629680, 1629684, 1629723, 1630162, 1630164, 1630165, 1630167, 1630168, 1630169, 1630170, 1630171, 1630172, 1630174, 1630178, 1630182, 1630183, 1630188, 1630191, 1630193, 1630194, 1630198, 1630200, 1630201, 1630202, 1630205, 1630208, 1630214, 1630224, 1630228, 1630230, 1630231, 1630245, 1630529, 1630530, 1630532, 1630533, 1630537, 1630538, 1630540, 1630541, 1630543, 1630544, 1630552, 1630557, 1630558, 1630559, 1630560, 1630570, 1630573, 1630577, 1630578, 1630581, 1630591, 1630595, 1630596, 1630598, 1630692, 1630700, 1630702, 1631093, 1631095, 1631097, 1631099, 1631100, 1631101, 1631105, 1631106, 1631110, 1631114, 1631117, 1631133, 1631212, 1631223, 1631323, 1713, 200768, 201142, 201143, 201144, 201145, 201566, 201567, 201569, 201572, 201935, 201939, 201942, 201950, 202330, 202331, 202681, 202685, 202691, 202694, 202695, 202696, 202699, 202704, 203076, 203081, 203083, 203110, 203114, 203468, 203471, 203482, 203484, 203486, 203497, 203501, 203552, 203897, 203903, 203914, 203915, 203924, 203926, 203932, 203935, 203944, 203952, 203954, 203967, 203991, 203994, 203999, 204001, 204456, 2199, 2200, 2403, 2544]

# %% [markdown]
# ### 2. The functions to process the data

# %%
import csv
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# The features we used in training models

# %%
combinedshottype_list = ['COMBINED_SHOT_TYPE_Jump Shot', 
               'COMBINED_SHOT_TYPE_Layup', 'COMBINED_SHOT_TYPE_Dunk', 'COMBINED_SHOT_TYPE_Tip Shot',
               'COMBINED_SHOT_TYPE_Hook Shot', 'COMBINED_SHOT_TYPE_Bank Shot']
feature_list = ['PERIOD', 'REMAIN_TIME', 'DIST', 'ANGLE'] + combinedshottype_list

# %% [markdown]
# Data Cleaning

# %%
# def clean_data(df_old, feature_list):
#     df = df_old.copy()
    
#     # Change the action type into combined shot type
#     action={'Jump Shot': 'Jump Shot', 'Driving Dunk Shot': 'Dunk', 'Layup Shot':'Layup',
#            'Running Jump Shot':'Jump Shot', 'Reverse Dunk Shot':'Dunk', 'Slam Dunk Shot':'Dunk',
#            'Driving Layup Shot':'Layup', 'Turnaround Jump Shot':'Jump Shot', 'Reverse Layup Shot':'Layup',
#            'Tip Shot':'Tip Shot', 'Running Hook Shot':'Hook Shot', 'Alley Oop Dunk Shot':'Dunk',
#            'Dunk Shot':'Dunk', 'Alley Oop Layup shot':'Layup', 'Running Dunk Shot':'Dunk',
#            'Driving Finger Roll Shot':'Layup', 'Running Layup Shot':'Layup',
#            'Finger Roll Shot':'Layup', 'Fadeaway Jump Shot':'Jump Shot', 'Follow Up Dunk Shot':'Dunk',
#            'Hook Shot':'Hook Shot', 'Turnaround Hook Shot':'Hook Shot', 'Jump Hook Shot':'Jump Shot',
#            'Running Finger Roll Shot':'Layup', 'Jump Bank Shot':'Jump Shot',
#            'Turnaround Finger Roll Shot':'Layup', 'Hook Bank Shot':'Bank Shot',
#            'Driving Hook Shot':'Hook Shot', 'Running Tip Shot':'Tip Shot',
#            'Running Reverse Layup Shot':'Layup', 'Driving Finger Roll Layup Shot':'Layup',
#            'Fadeaway Bank shot':'Bank Shot', 'Pullup Jump shot':'Jump Shot', 'Finger Roll Layup Shot':'Layup',
#            'Turnaround Fadeaway shot':'Jump Shot', 'Driving Reverse Layup Shot':'Layup',
#            'Driving Slam Dunk Shot':'Dunk', 'Step Back Jump shot':'Jump Shot',
#            'Turnaround Bank shot':'Bank Shot', 'Reverse Slam Dunk Shot':'Dunk',
#            'Floating Jump shot':'Jump Shot', 'Putback Slam Dunk Shot':'Dunk',
#            'Running Bank shot':'Bank Shot', 'Driving Bank shot':'Bank Shot', 'Driving Jump shot':'Jump Shot',
#            'Putback Layup Shot':'Layup', 'Putback Dunk Shot':'Dunk',
#            'Running Finger Roll Layup Shot':'Layup', 'Pullup Bank shot':'Bank Shot',
#            'Running Slam Dunk Shot':'Dunk', 'Cutting Layup Shot':'Layup',
#            'Driving Floating Jump Shot':'Jump Shot', 'Running Pull-Up Jump Shot':'Jump Shot',
#            'Tip Layup Shot':'Layup', 'Driving Floating Bank Jump Shot':'Jump Shot',
#            'Cutting Finger Roll Layup Shot':'Layup', 'Turnaround Fadeaway Bank Jump Shot':'Jump Shot',
#            'Step Back Bank Jump Shot':'Jump Shot', 'Cutting Dunk Shot':'Dunk', 'Running Bank Hook Shot': 'Hook Shot', 
#             'Turnaround Bank Hook Shot': 'Hook Shot', 'Tip Dunk Shot': 'Dunk', 'Driving Reverse Dunk Shot': 'Dunk', 
#            'Jump Bank Hook Shot': 'Jump Shot', 'Driving Bank Hook Shot': 'Bank Shot', 'No Shot': 'Jump Shot', 
#            'Running Alley Oop Layup Shot': 'Layup', 'Running Alley Oop Dunk Shot': 'Dunk', 
#            'Running Reverse Dunk Shot':'Dunk', 'Putback Reverse Dunk Shot': 'Dunk'}
    
#     df['COMBINED_SHOT_TYPE']=df.ACTION_TYPE.apply(lambda x:action[x])
#     df=df.drop('ACTION_TYPE', axis=1)
    
#     # Combine the minutes_remaining and seconds_remaining into remain_time
#     df['REMAIN_TIME'] = df['MINUTES_REMAINING'] * 60 + df['SECONDS_REMAINING']
#     df = df.drop(['MINUTES_REMAINING', 'SECONDS_REMAINING'], axis = 1)
    
#     # Compute the shot distance and shot angle from loc_x and loc_y
#     df['DIST']=(df.LOC_X**2+df.LOC_Y**2)**0.5
#     df['ANGLE']=np.arctan2(df.LOC_X,df.LOC_Y)/np.pi*180.0
    
#     # Use the one-hot coding for combined_shot_type
#     features_onehot = ['COMBINED_SHOT_TYPE']
#     for i in features_onehot:
#         df = pd.concat([df, pd.get_dummies(df[i], prefix=i)], axis=1)
#         df = df.drop(i, axis=1)

    
#     # If the column of required feature is empty, fill the column with 0
#     for i in feature_list:
#         if i not in df.columns.values:
#             df[i] = 0
    
#     # Exclude the shot from back court
#     df = df[df.DIST < 320.0]
    
#     # Extract required features from data frame
#     df = df[feature_list+['SHOT_MADE_FLAG']]
    
#     return df

import pandas as pd
import numpy as np

def clean_data(df_old, feature_list):
    df = df_old.copy()
    
    # Simplifying shot types into broader categories
    #     # Change the action type into combined shot type
    action_map ={'Jump Shot': 'Jump Shot', 'Driving Dunk Shot': 'Dunk', 'Layup Shot':'Layup',
           'Running Jump Shot':'Jump Shot', 'Reverse Dunk Shot':'Dunk', 'Slam Dunk Shot':'Dunk',
           'Driving Layup Shot':'Layup', 'Turnaround Jump Shot':'Jump Shot', 'Reverse Layup Shot':'Layup',
           'Tip Shot':'Tip Shot', 'Running Hook Shot':'Hook Shot', 'Alley Oop Dunk Shot':'Dunk',
           'Dunk Shot':'Dunk', 'Alley Oop Layup shot':'Layup', 'Running Dunk Shot':'Dunk',
           'Driving Finger Roll Shot':'Layup', 'Running Layup Shot':'Layup',
           'Finger Roll Shot':'Layup', 'Fadeaway Jump Shot':'Jump Shot', 'Follow Up Dunk Shot':'Dunk',
           'Hook Shot':'Hook Shot', 'Turnaround Hook Shot':'Hook Shot', 'Jump Hook Shot':'Jump Shot',
           'Running Finger Roll Shot':'Layup', 'Jump Bank Shot':'Jump Shot',
           'Turnaround Finger Roll Shot':'Layup', 'Hook Bank Shot':'Bank Shot',
           'Driving Hook Shot':'Hook Shot', 'Running Tip Shot':'Tip Shot',
           'Running Reverse Layup Shot':'Layup', 'Driving Finger Roll Layup Shot':'Layup',
           'Fadeaway Bank shot':'Bank Shot', 'Pullup Jump shot':'Jump Shot', 'Finger Roll Layup Shot':'Layup',
           'Turnaround Fadeaway shot':'Jump Shot', 'Driving Reverse Layup Shot':'Layup',
           'Driving Slam Dunk Shot':'Dunk', 'Step Back Jump shot':'Jump Shot',
           'Turnaround Bank shot':'Bank Shot', 'Reverse Slam Dunk Shot':'Dunk',
           'Floating Jump shot':'Jump Shot', 'Putback Slam Dunk Shot':'Dunk',
           'Running Bank shot':'Bank Shot', 'Driving Bank shot':'Bank Shot', 'Driving Jump shot':'Jump Shot',
           'Putback Layup Shot':'Layup', 'Putback Dunk Shot':'Dunk',
           'Running Finger Roll Layup Shot':'Layup', 'Pullup Bank shot':'Bank Shot',
           'Running Slam Dunk Shot':'Dunk', 'Cutting Layup Shot':'Layup',
           'Driving Floating Jump Shot':'Jump Shot', 'Running Pull-Up Jump Shot':'Jump Shot',
           'Tip Layup Shot':'Layup', 'Driving Floating Bank Jump Shot':'Jump Shot',
           'Cutting Finger Roll Layup Shot':'Layup', 'Turnaround Fadeaway Bank Jump Shot':'Jump Shot',
           'Step Back Bank Jump Shot':'Jump Shot', 'Cutting Dunk Shot':'Dunk', 'Running Bank Hook Shot': 'Hook Shot', 
            'Turnaround Bank Hook Shot': 'Hook Shot', 'Tip Dunk Shot': 'Dunk', 'Driving Reverse Dunk Shot': 'Dunk', 
           'Jump Bank Hook Shot': 'Jump Shot', 'Driving Bank Hook Shot': 'Bank Shot', 'No Shot': 'Jump Shot', 
           'Running Alley Oop Layup Shot': 'Layup', 'Running Alley Oop Dunk Shot': 'Dunk', 
           'Running Reverse Dunk Shot':'Dunk', 'Putback Reverse Dunk Shot': 'Dunk'}
    
    df['COMBINED_SHOT_TYPE'] = df['ACTION_TYPE'].map(action_map)

    # Calculate remaining time in seconds as a single feature
    df['REMAINING_TIME'] = df['MINUTES_REMAINING'] * 60 + df['SECONDS_REMAINING']

    # Calculate distance from the hoop and angle
    df['DISTANCE'] = np.sqrt(df['LOC_X']**2 + df['LOC_Y']**2)
    df['ANGLE'] = np.degrees(np.arctan2(df['LOC_Y'], df['LOC_X']))

    # One-hot encode categorical variables
    df = pd.get_dummies(df, columns=['COMBINED_SHOT_TYPE', 'PERIOD'])

    # Fill any NaNs which might disrupt the model
    df.fillna(0, inplace=True)

    # Ensure only required features are included
    df = df[feature_list + ['SHOT_MADE_FLAG']]
    return df

# %%
from sklearn.metrics import make_scorer, roc_auc_score

def evaluate_model(X, y, cv_strategy, pipeline, param_grid):
    # Run grid search with the specified pipeline and parameters
    grid_search = GridSearchCV(estimator=pipeline, 
                               param_grid=param_grid, 
                               cv=StratifiedKFold(5), 
                               scoring=make_scorer(roc_auc_score), verbose=1)
    grid_search.fit(X, y)
    
    # Extract the best parameters and the best score
    best_params = grid_search.best_params_
    best_score = grid_search.best_score_
    # Best model evaluation
    print("Best parameters:", grid_search.best_params_)
    print("Best cross-validation ROC AUC score: {:.2f}".format(grid_search.best_score_))

    # Evaluate on the test set
    roc_auc = roc_auc_score(y, grid_search.predict_proba(X)[:, 1])
    print("Test ROC AUC: {:.2f}".format(roc_auc))
    return best_params, best_score

# %%
with open('Players_Model.csv', 'w', newline='') as f_rslt:
    writer = csv.writer(f_rslt)
    writer.writerow(['PLAYER_ID', 'PLAYER_NAME', 'BEST_ROC_AUC'])

    scaler = StandardScaler()
    cv_strategy = StratifiedKFold(n_splits=5)
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('smote', SMOTE(random_state=42)),
        ('classifier', LogisticRegression(solver='lbfgs', random_state=42))
    ])

    param_grid = {
        'classifier__C': [0.01, 0.1, 1, 10],
        'classifier__penalty': ['l2']  # Only 'l2' is compatible with 'lbfgs'
    }


    for filepath in fpath_list:
        df = pd.read_csv(filepath)
        if df.empty:
            continue
        feature_list = ['DISTANCE', 'ANGLE', 'REMAINING_TIME']
        df_cleaned = clean_data(df, feature_list)
        X = df_cleaned.drop('SHOT_MADE_FLAG', axis=1)
        y = df_cleaned['SHOT_MADE_FLAG']
        X_scaled = scaler.fit_transform(X)

        best_params, best_score = evaluate_model(X_scaled, y, cv_strategy, pipeline, param_grid)
        
        print(f"Player ID: {df.PLAYER_ID.iloc[0]}")
        print(f"Player Name: {df.PLAYER_NAME.iloc[0]}")
        print(f"Best Parameters: {best_params}")
        print(f"Best ROC AUC: {best_score}\n")

        writer.writerow([df.PLAYER_ID.iloc[0], df.PLAYER_NAME.iloc[0], best_score])

print("Model training and evaluation complete.")
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.53
# Player ID: 101108
# Player Name: Chris Paul
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5140481962481962
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1626145
# Player Name: Tyus Jones
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5239808913696358
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1626156
# Player Name: D'Angelo Russell
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5090097970125329
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.51
# Player ID: 1626157
# Player Name: Karl-Anthony Towns
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4698876760223049
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.54
# Player ID: 1626162
# Player Name: Kelly Oubre Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5271902710957029
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1626166
# Player Name: Cameron Payne
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5142787310076361
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1626167
# Player Name: Myles Turner
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48498273982639306
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1626168
# Player Name: Trey Lyles
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5152665899501342
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1626171
# Player Name: Bobby Portis
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.511445723463114
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1626172
# Player Name: Kevon Looney
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47325882404269864
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1626179
# Player Name: Terry Rozier
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5161149254599906
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 1626181
# Player Name: Norman Powell
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4824604340450637
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.52
# Player ID: 1626192
# Player Name: Pat Connaughton
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5314648199023198
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.45
# Test ROC AUC: 0.49
# Player ID: 1626196
# Player Name: Josh Richardson
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.44686078520218137
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.55
# Player ID: 1626204
# Player Name: Larry Nance Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5293506057895593
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1626220
# Player Name: Royce O'Neale
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5280447213484275
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1626224
# Player Name: Cedi Osman
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49475345808426463
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.54
# Player ID: 1627734
# Player Name: Domantas Sabonis
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5289881815877381
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.55
# Test ROC AUC: 0.55
# Player ID: 1627739
# Player Name: Kris Dunn
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5456095791001452
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1627741
# Player Name: Buddy Hield
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4964932547069081
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 1627742
# Player Name: Brandon Ingram
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49353356681674543
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1627747
# Player Name: Caris LeVert
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5139603978697285
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1627749
# Player Name: Dejounte Murray
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5093378910570905
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1627750
# Player Name: Jamal Murray
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5081412303309726
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.49
# Player ID: 1627751
# Player Name: Jakob Poeltl
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48453230318041224
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1627752
# Player Name: Taurean Prince
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4742944231203432
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1627777
# Player Name: Georges Niang
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5256317608231411
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.52
# Player ID: 1627783
# Player Name: Pascal Siakam
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5040962082467265
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1627826
# Player Name: Ivica Zubac
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.512172491408252
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.52
# Player ID: 1627827
# Player Name: Dorian Finney-Smith
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5036161678894302
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.51
# Player ID: 1627832
# Player Name: Fred VanVleet
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5247819672529468
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1627884
# Player Name: Derrick Jones Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4882288324541846
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1627936
# Player Name: Alex Caruso
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4811338868110009
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.53
# Player ID: 1628365
# Player Name: Markelle Fultz
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5038487848784878
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 1628368
# Player Name: De'Aaron Fox
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5165198607943087
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 1628369
# Player Name: Jayson Tatum
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4787589354686023
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1628370
# Player Name: Malik Monk
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.525146581489017
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.55
# Test ROC AUC: 0.55
# Player ID: 1628372
# Player Name: Dennis Smith Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5475218645367899
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1628374
# Player Name: Lauri Markkanen
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5142174708493926
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1628378
# Player Name: Donovan Mitchell
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49874385338130417
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 1628379
# Player Name: Luke Kennard
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4854220788467364
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.46
# Test ROC AUC: 0.50
# Player ID: 1628380
# Player Name: Zach Collins
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.45775862068965517
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1628381
# Player Name: John Collins
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4758065467160206
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1628392
# Player Name: Isaiah Hartenstein
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4739715141512317
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 1628398
# Player Name: Kyle Kuzma
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5249408669366954
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1628401
# Player Name: Derrick White
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47815732763713187
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.52
# Player ID: 1628404
# Player Name: Josh Hart
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5023786131996658
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1628420
# Player Name: Monte Morris
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5129043430333455
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 1628470
# Player Name: Torrey Craig
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4855451614376304
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.52
# Player ID: 1628975
# Player Name: Jevon Carter
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5039377990430622
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 1628976
# Player Name: Wendell Carter Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4920991730952412
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.54
# Player ID: 1628978
# Player Name: Donte DiVincenzo
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5323449945733767
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.50
# Player ID: 1628983
# Player Name: Shai Gilgeous-Alexander
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5072417582417582
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1628984
# Player Name: Devonte' Graham
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5040987933634992
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.54
# Test ROC AUC: 0.53
# Player ID: 1628988
# Player Name: Aaron Holiday
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5378076540048371
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1628989
# Player Name: Kevin Huerter
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4858046662321514
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1628991
# Player Name: Jaren Jackson Jr.
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5120591373169543
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.52
# Player ID: 1628995
# Player Name: Kevin Knox II
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4896719858156028
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1628997
# Player Name: Caleb Martin
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5160667780637974
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1629001
# Player Name: De'Anthony Melton
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5117109085823424
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.46
# Test ROC AUC: 0.52
# Player ID: 1629003
# Player Name: Shake Milton
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.46323444873444874
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.53
# Player ID: 1629006
# Player Name: Josh Okogie
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5102198933627504
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1629008
# Player Name: Michael Porter Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5194997295361757
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.52
# Player ID: 1629012
# Player Name: Collin Sexton
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5256416191369545
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1629013
# Player Name: Landry Shamet
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.510230179028133
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1629014
# Player Name: Anfernee Simons
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5129999199559533
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1629018
# Player Name: Gary Trent Jr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5057120128124085
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1629020
# Player Name: Jarred Vanderbilt
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5346871104134612
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.55
# Player ID: 1629021
# Player Name: Moritz Wagner
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5326743632210784
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1629022
# Player Name: Lonnie Walker IV
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4733778922591819
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.52
# Player ID: 1629023
# Player Name: P.J. Washington
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5281140277700687
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1629026
# Player Name: Kenrich Williams
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5152841781874039
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.50
# Player ID: 1629027
# Player Name: Trae Young
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5009700560743322
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 1629029
# Player Name: Luka Doncic
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5194368136079979
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1629060
# Player Name: Rui Hachimura
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5270189217097896
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.45
# Test ROC AUC: 0.52
# Player ID: 1629111
# Player Name: Jock Landale
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.44862027807074245
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.54
# Player ID: 1629130
# Player Name: Duncan Robinson
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5272580457107925
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1629216
# Player Name: Gabe Vincent
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5076369737084023
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1629234
# Player Name: Drew Eubanks
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4752305739084967
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1629312
# Player Name: Haywood Highsmith
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5122844459817826
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1629611
# Player Name: Terance Mann
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4812329055333474
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1629614
# Player Name: Andrew Nembhard
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5208118692610424
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1629622
# Player Name: Max Strus
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5202414956011729
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.54
# Test ROC AUC: 0.56
# Player ID: 1629629
# Player Name: Cam Reddish
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5431766067810948
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 1629630
# Player Name: Ja Morant
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48005227824556707
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1629631
# Player Name: De'Andre Hunter
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5134921253490289
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1629632
# Player Name: Coby White
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49654966543608675
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1629636
# Player Name: Darius Garland
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5180574115639411
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1629639
# Player Name: Tyler Herro
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47112126216695016
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1629640
# Player Name: Keldon Johnson
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4835721816853328
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.51
# Player ID: 1629651
# Player Name: Nic Claxton
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.516000666000666
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 1629652
# Player Name: Luguentz Dort
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48466629834254144
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1629655
# Player Name: Daniel Gafford
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4932850107499861
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.53
# Player ID: 1629656
# Player Name: Quentin Grimes
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4952865961199294
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.54
# Test ROC AUC: 0.53
# Player ID: 1629659
# Player Name: Talen Horton-Tucker
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5361194805194806
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.52
# Player ID: 1629661
# Player Name: Cameron Johnson
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4876293687480128
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1629667
# Player Name: Jalen McDaniels
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4885841694537347
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1629670
# Player Name: Jordan Nwora
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5045011454185098
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.51
# Player ID: 1629673
# Player Name: Jordan Poole
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5220018087140588
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.52
# Player ID: 1629675
# Player Name: Naz Reid
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5300763740305244
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1629680
# Player Name: Matisse Thybulle
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5016830739917435
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1629684
# Player Name: Grant Williams
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5257026771805097
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.51
# Player ID: 1629723
# Player Name: John Konchar
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5315700483091786
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.51
# Player ID: 1630162
# Player Name: Anthony Edwards
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5224593109279221
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 1630164
# Player Name: James Wiseman
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47702927654566185
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1630165
# Player Name: Killian Hayes
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5140062990370278
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1630167
# Player Name: Obi Toppin
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47074099271823755
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 1630168
# Player Name: Onyeka Okongwu
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49479166666666663
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.53
# Player ID: 1630169
# Player Name: Tyrese Haliburton
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5115317016036663
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1630170
# Player Name: Devin Vassell
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5323553460445265
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.56
# Test ROC AUC: 0.56
# Player ID: 1630171
# Player Name: Isaac Okoro
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5576972740315639
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.51
# Player ID: 1630172
# Player Name: Patrick Williams
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4710503912294387
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1630174
# Player Name: Aaron Nesmith
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.46561894324838893
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 1630178
# Player Name: Tyrese Maxey
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5325006171424436
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 1630182
# Player Name: Josh Green
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5234199543319946
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.52
# Player ID: 1630183
# Player Name: Jaden McDaniels
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.530512850009754
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.51
# Player ID: 1630188
# Player Name: Jalen Smith
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4680114809081527
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1630191
# Player Name: Isaiah Stewart
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5085760558188115
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.50
# Player ID: 1630193
# Player Name: Immanuel Quickley
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.500100638289632
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1630194
# Player Name: Paul Reed
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.486523312752821
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1630198
# Player Name: Isaiah Joe
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4870861051847548
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 1630200
# Player Name: Tre Jones
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4777990979309575
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 1630201
# Player Name: Malachi Flynn
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5190252912759308
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1630202
# Player Name: Payton Pritchard
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48868327143606394
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1630205
# Player Name: Lamar Stevens
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4749526167767181
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.53
# Player ID: 1630208
# Player Name: Nick Richards
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5071298960059367
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1630214
# Player Name: Xavier Tillman
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4682799260007087
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1630224
# Player Name: Jalen Green
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.489865528730036
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 1630228
# Player Name: Jonathan Kuminga
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5175954254079255
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 1630230
# Player Name: Naji Marshall
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49648109268758206
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 1630231
# Player Name: KJ Martin
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4881995573977468
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 1630245
# Player Name: Ayo Dosunmu
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4732191972271914
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.54
# Test ROC AUC: 0.55
# Player ID: 1630529
# Player Name: Herbert Jones
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5406368228066342
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 1630530
# Player Name: Trey Murphy III
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4869980003943322
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 1630532
# Player Name: Franz Wagner
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5122811410962952
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.54
# Test ROC AUC: 0.58
# Player ID: 1630533
# Player Name: Ziaire Williams
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5379744229280761
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 1630537
# Player Name: Chris Duarte
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5106426570032322
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.50
# Player ID: 1630538
# Player Name: Bones Hyland
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5002767938063409
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.52
# Player ID: 1630540
# Player Name: Miles McBride
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4996012759170654
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 1630541
# Player Name: Moses Moody
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48032723994801063
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.49
# Player ID: 1630543
# Player Name: Isaiah Jackson
# ...
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 201939
# Player Name: Stephen Curry
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5165919278890354
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 201942
# Player Name: DeMar DeRozan
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.524894302950776
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.53
# Player ID: 201950
# Player Name: Jrue Holiday
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5119891209718009
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.52
# Player ID: 202330
# Player Name: Gordon Hayward
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4898703563850829
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.51
# Player ID: 202331
# Player Name: Paul George
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47213717035012637
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 202681
# Player Name: Kyrie Irving
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4817807313459487
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.52
# Player ID: 202685
# Player Name: Jonas Valanciunas
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5255502038793128
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 202691
# Player Name: Klay Thompson
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.511267876920883
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.55
# Test ROC AUC: 0.56
# Player ID: 202694
# Player Name: Marcus Morris Sr.
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5489881240024015
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 202695
# Player Name: Kawhi Leonard
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5000365344389918
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 202696
# Player Name: Nikola Vucevic
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5089872580839043
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 202699
# Player Name: Tobias Harris
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5100269755002186
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.54
# Player ID: 202704
# Player Name: Reggie Jackson
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5309237831377662
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.51
# Player ID: 203076
# Player Name: Anthony Davis
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5240847306564134
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.50
# Player ID: 203081
# Player Name: Damian Lillard
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4958501305282249
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.52
# Player ID: 203083
# Player Name: Andre Drummond
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.502605777675946
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.55
# Test ROC AUC: 0.56
# Player ID: 203110
# Player Name: Draymond Green
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5534116688845763
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.52
# Player ID: 203114
# Player Name: Khris Middleton
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4731674160245588
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 203468
# Player Name: CJ McCollum
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5002239053856217
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 203471
# Player Name: Dennis Schroder
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49373083372708154
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 203482
# Player Name: Kelly Olynyk
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49822222222222223
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.49
# Player ID: 203484
# Player Name: Kentavious Caldwell-Pope
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4798774351872542
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.54
# Player ID: 203486
# Player Name: Mason Plumlee
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5339717310801648
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 203497
# Player Name: Rudy Gobert
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4950836249049205
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.53
# Player ID: 203501
# Player Name: Tim Hardaway Jr.
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5172146985586206
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.46
# Test ROC AUC: 0.52
# Player ID: 203552
# Player Name: Seth Curry
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.46083356122947894
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.52
# Test ROC AUC: 0.52
# Player ID: 203897
# Player Name: Zach LaVine
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5198318892394773
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.50
# Player ID: 203903
# Player Name: Jordan Clarkson
# Best Parameters: {'classifier__C': 1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4922842038100447
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 203914
# Player Name: Gary Harris
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5107237303097624
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.51
# Player ID: 203915
# Player Name: Spencer Dinwiddie
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47704801677351805
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 203924
# Player Name: Jerami Grant
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5069568484096773
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.52
# Player ID: 203926
# Player Name: Doug McDermott
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49495091363068894
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.52
# Player ID: 203932
# Player Name: Aaron Gordon
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4941772693310239
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 203935
# Player Name: Marcus Smart
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.48407821931589534
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 203944
# Player Name: Julius Randle
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5060812734923511
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 203952
# Player Name: Andrew Wiggins
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4986623418489956
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.50
# Test ROC AUC: 0.51
# Player ID: 203954
# Player Name: Joel Embiid
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49979592171261855
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.47
# Test ROC AUC: 0.50
# Player ID: 203967
# Player Name: Dario Saric
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4729744055732243
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.49
# Test ROC AUC: 0.51
# Player ID: 203991
# Player Name: Clint Capela
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.49253061332908327
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 203994
# Player Name: Jusuf Nurkic
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5280029740374568
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.52
# Player ID: 203999
# Player Name: Nikola Jokic
# Best Parameters: {'classifier__C': 0.1, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.508516623103346
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.48
# Test ROC AUC: 0.50
# Player ID: 204001
# Player Name: Kristaps Porzingis
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.47777130267708506
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.51
# Test ROC AUC: 0.51
# Player ID: 204456
# Player Name: T.J. McConnell
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5115480676416302
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.45
# Test ROC AUC: 0.50
# Player ID: 2199
# Player Name: Tyson Chandler
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.4456257210132904
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.55
# Test ROC AUC: 0.53
# Player ID: 2200
# Player Name: Pau Gasol
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5497365743337996
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.45
# Test ROC AUC: 0.50
# Player ID: 2403
# Player Name: Nene
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.45134336239230455
#
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Best parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best cross-validation ROC AUC score: 0.53
# Test ROC AUC: 0.53
# Player ID: 2544
# Player Name: LeBron James
# Best Parameters: {'classifier__C': 0.01, 'classifier__penalty': 'l2'}
# Best ROC AUC: 0.5287545625542821
#
# Model training and evaluation complete.

# %% [markdown]
# Function to train the model

# %%
def TrainModel(df, scaler=None):
    if df.empty:
        return [float('nan')] * len(df.columns[:-1]), float('nan')  # handle empty DataFrame case
    X = df.drop('SHOT_MADE_FLAG', axis=1)
    y = df['SHOT_MADE_FLAG']
    if scaler is not None:
        X = scaler.transform(X)
    clf = LogisticRegression(C=1.0, max_iter=300, solver='lbfgs')
    clf.fit(X, y)
    coef = list(map(float, clf.coef_[0]))
    intercept = float(clf.intercept_[0])
    return coef, intercept

# %%
df
# Out:
#               GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID PLAYER_NAME  \
# 0     Shot Chart Detail  22200013             17     101108  Chris Paul
# 1     Shot Chart Detail  22200013            212     101108  Chris Paul
# 2     Shot Chart Detail  22200013            230     101108  Chris Paul
# 3     Shot Chart Detail  22200013            248     101108  Chris Paul
# 4     Shot Chart Detail  22200013            467     101108  Chris Paul
# ...                 ...       ...            ...        ...         ...
# 1130  Shot Chart Detail  22301198            409     101108  Chris Paul
# 1131  Shot Chart Detail  22301214            200     101108  Chris Paul
# 1132  Shot Chart Detail  22301214            343     101108  Chris Paul
# 1133  Shot Chart Detail  22301214            528     101108  Chris Paul
# 1134  Shot Chart Detail  22301214            567     101108  Chris Paul
#
#          TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0     1610612756           Phoenix Suns       1                 10
# 1     1610612756           Phoenix Suns       2                  8
# 2     1610612756           Phoenix Suns       2                  7
# 3     1610612756           Phoenix Suns       2                  6
# 4     1610612756           Phoenix Suns       3                  4
# ...          ...                    ...     ...                ...
# 1130  1610612744  Golden State Warriors       3                  6
# 1131  1610612744  Golden State Warriors       2                 11
# 1132  1610612744  Golden State Warriors       2                  1
# 1133  1610612744  Golden State Warriors       4                 11
# 1134  1610612744  Golden State Warriors       4                  8
#
#       SECONDS_REMAINING  ...         SHOT_ZONE_AREA SHOT_ZONE_RANGE  \
# 0                    51  ...              Center(C)         24+ ft.
# 1                    16  ...              Center(C)        8-16 ft.
# 2                    22  ...          Right Side(R)        8-16 ft.
# 3                     0  ...              Center(C)        8-16 ft.
# 4                    29  ...           Left Side(L)       16-24 ft.
# ...                 ...  ...                    ...             ...
# 1130                 24  ...  Right Side Center(RC)       16-24 ft.
# 1131                  4  ...   Left Side Center(LC)         24+ ft.
# 1132                 57  ...              Center(C)       16-24 ft.
# 1133                 50  ...           Left Side(L)        8-16 ft.
# 1134                 26  ...   Left Side Center(LC)         24+ ft.
#
#      SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0               26    61   253                   1               0   20221019
# 1               12     5   127                   1               0   20221019
# 2               13   134    25                   1               1   20221019
# 3               13    66   117                   1               0   20221019
# 4               16  -156    67                   1               0   20221019
# ...            ...   ...   ...                 ...             ...        ...
# 1130            19    97   168                   1               0   20240414
# 1131            26  -176   194                   1               0   20231206
# 1132            19    58   183                   1               1   20231206
# 1133            13  -117    67                   1               0   20231206
# 1134            25  -184   173                   1               0   20231206
#
#       HTM  VTM
# 0     PHX  DAL
# 1     PHX  DAL
# 2     PHX  DAL
# 3     PHX  DAL
# 4     PHX  DAL
# ...   ...  ...
# 1130  GSW  UTA
# 1131  GSW  POR
# 1132  GSW  POR
# 1133  GSW  POR
# 1134  GSW  POR
#
# [1135 rows x 24 columns]

# %% [markdown]
# Begin training for all players
# Save the coefficients into a csv file

# %%
with open('Players_Model.csv', 'w', newline='') as f_rslt:
    writer = csv.writer(f_rslt)
    writer.writerow(['PLAYER_ID', 'PLAYER_NAME'] + feature_list + ['INTERCEPT'])
    scaler = StandardScaler()  # Optionally consider global fitting if data available
    for i, filepath in enumerate(fpath_list):
        df = pd.read_csv(filepath)
        if df.empty:
            continue  # Skip processing for empty data files
        player_id = int(df.PLAYER_ID.iloc[0])
        player_name = str(df.PLAYER_NAME.iloc[0])
        df = clean_data(df, feature_list)
        if df.empty:
            writer.writerow([player_id, player_name] + [float('nan')] * len(feature_list) + [float('nan')])
            continue
        if i == 0:
            scaler.fit(df.drop('SHOT_MADE_FLAG', axis=1))  # Fit scaler only once if global data not pooled
        coef, intercept = TrainModel(df, scaler)


        writer.writerow([player_id, player_name] + coef + [intercept])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 11
#       9 player_id = int(df.PLAYER_ID.iloc[0])
#      10 player_name = str(df.PLAYER_NAME.iloc[0])
# ---> 11 df = clean_data(df, feature_list)
#      12 if df.empty:
#      13     writer.writerow([player_id, player_name] + [float('nan')] * len(feature_list) + [float('nan')])
#
# Cell In[27], line 114, in clean_data(df_old, feature_list)
#     111 df['ANGLE'] = np.degrees(np.arctan2(df['LOC_Y'], df['LOC_X']))
#     113 # One-hot encode categorical variables
# --> 114 df = pd.get_dummies(df, columns=['COMBINED_SHOT_TYPE', 'PERIOD', 'SEASON'])
#     116 # Fill any NaNs which might disrupt the model
#     117 df.fillna(0, inplace=True)
#
# File c:\Users\joyce\Documents\GitHub\NBA-Shot-Analysis\.venv\Lib\site-packages\pandas\core\reshape\encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File c:\Users\joyce\Documents\GitHub\NBA-Shot-Analysis\.venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\joyce\Documents\GitHub\NBA-Shot-Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\joyce\Documents\GitHub\NBA-Shot-Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['SEASON'] not in index"
